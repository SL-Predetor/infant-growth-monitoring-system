# %%
from deepface import DeepFace
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC  # Support Vector Classifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

import tensorflow as tf
import os
import pandas as pd
import seaborn as sns
import time
import sys

# %%
# Check if TensorFlow can access GPU
if tf.config.list_physical_devices('GPU'):
    print("GPU is available.")
    # Get GPU details
    physical_devices = tf.config.list_physical_devices('GPU')
    for device in physical_devices:
        print(f"Device: {device}")
        # Show device details like name and memory info
        from tensorflow.python.client import device_lib
        local_device_protos = device_lib.list_local_devices()
        for device in local_device_protos:
            if device.device_type == 'GPU':
                print(f"Name: {device.name}")
                print(f"Memory Limit: {device.memory_limit / 1024 / 1024} MB")
else:
    print("No GPU available.")
# Out:
# GPU is available.
# Device: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Name: /device:GPU:0
# Memory Limit: 3460.20703125 MB

# %%
import sys
import importlib.metadata

# List of your imported packages
packages = ["deepface", "opencv-python", "numpy", "matplotlib", 
            "scikit-learn", "tensorflow", "pandas", "seaborn"]

print(f"Python version: {sys.version}")

for pkg in packages:
    try:
        version = importlib.metadata.version(pkg)
        print(f"{pkg}: {version}")
    except importlib.metadata.PackageNotFoundError:
        print(f"{pkg}: Not found")
# Out:
# Python version: 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]
# deepface: 0.0.96
# opencv-python: 4.6.0.66
# numpy: 1.23.5
# matplotlib: 3.10.8
# scikit-learn: 1.7.2
# tensorflow: 2.10.0
# pandas: 2.3.3
# seaborn: 0.13.2

# %%
# embeddings = DeepFace.represent(img_path = "image.jpg", 
#                                 model_name = "Facenet512", 
#                                 detector_backend = "retinaface")

# %% [markdown]
# Step 2

# %%
import tensorflow as tf
import os

# --- 1. Define Paths and Constants ---
DATA_DIR = r"C:\Users\Yasindu\Desktop\Stuff\1.SLIIT\Research\Project\data\imgData\prepImg\step4"
IMG_SIZE = (224, 224) 
BATCH_SIZE = 32
SEED = 123             

# --- 2. Load the Dataset ---
# 80% Training
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary'
)

# 20% for Val and Test
remaining_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary'
)

# Final split for 10% Test / 10% Val
val_batches = tf.data.experimental.cardinality(remaining_ds)
test_ds = remaining_ds.take(val_batches // 2)
val_ds = remaining_ds.skip(val_batches // 2)

# --- 3. Combined Preprocessing (Normalization + Label Flip) ---
# We do this in ONE step to save computation time.
normalization_layer = tf.keras.layers.Rescaling(1./255)

def preprocess(x, y):
    # Normalize pixels to [0, 1]
    x = normalization_layer(x)
    # Flip labels so Autistic (alphabetically first, so 0) becomes 1
    y = 1 - y
    return x, y

train_ds = train_ds.map(preprocess)
val_ds = val_ds.map(preprocess)
test_ds = test_ds.map(preprocess)

# --- 4. Performance Optimization ---
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

print("\n--- Data Preparation Complete ---")
print("Confirmed: Autistic is now labeled 1, Non_Autistic is labeled 0.")
# Out:
# Found 3917 files belonging to 2 classes.
# Using 3134 files for training.
# Found 3917 files belonging to 2 classes.
# Using 783 files for validation.
#
# --- Data Preparation Complete ---
# Confirmed: Autistic is now labeled 1, Non_Autistic is labeled 0.

# %%
for images, labels in train_ds.take(1):
    print(f"Sample Batch Labels: {labels.numpy().flatten()[:5]}")
    print(f"Pixel Max: {tf.reduce_max(images).numpy()}") # Should be <= 1.0
# Out:
# Sample Batch Labels: [1. 0. 1. 1. 1.]
# Pixel Max: 1.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from deepface import DeepFace

# --- 1. Load the Pre-trained Backbone ---
vgg_model_wrapper = DeepFace.build_model("VGG-Face")
full_vgg_face = vgg_model_wrapper.model 

# --- 2. Strip away the recognition layers ---
# Based on your error log, 'conv2d_14' is the final feature-rich layer.
backbone_output = full_vgg_face.get_layer("conv2d_14").output
feature_extractor = Model(inputs=full_vgg_face.input, outputs=backbone_output)

# --- 3. Freeze the Backbone Layers ---
feature_extractor.trainable = False

# --- 4. Attach the Custom Head ---
inputs = Input(shape=(224, 224, 3), name="face_input")

# Pass input through frozen backbone
# training=False is critical to keep the model in inference mode
x = feature_extractor(inputs, training=False)

# A. Global Average Pooling 
# This converts the 2D output of conv2d_14 into a 1D vector
x = GlobalAveragePooling2D()(x)

# B. Dense Layer (ASD Feature Learner)
feature_layer = Dense(256, activation='relu', name='asd_feature_vector')(x)

# C. Output Layer (Sigmoid for binary probability)
prediction = Dense(1, activation='sigmoid', name='classification_output')(feature_layer)

# --- 5. Build the Unified Model ---
# This meets your requirement for dual outputs (prediction + feature vector)
unified_model = Model(inputs=inputs, outputs=[prediction, feature_layer])

# Verify
unified_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  face_input (InputLayer)     [(None, 224, 224, 3)]     0
#
#  model_1 (Functional)        (None, 1, 1, 4096)        134260544
#
#  global_average_pooling2d (G  (None, 4096)             0
#  lobalAveragePooling2D)
#
#  asd_feature_vector (Dense)  (None, 256)               1048832
#
#  classification_output (Dens  (None, 1)                257
#  e)
#
# =================================================================
# Total params: 135,309,633
# Trainable params: 1,049,089
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %%
# Adjust datasets to handle the dual-output architecture
def map_for_dual_output(img, label):
    # The first 'label' is for classification_output
    # The second 'None' tells Keras not to calculate loss for the feature_vector output
    return img, {'classification_output': label, 'asd_feature_vector': label}

train_ds_final = train_ds.map(map_for_dual_output)
val_ds_final = val_ds.map(map_for_dual_output)
test_ds_final = test_ds.map(map_for_dual_output)

# %%
unified_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss={
        'classification_output': 'binary_crossentropy',
        'asd_feature_vector': None # No loss for the feature vector output
    },
    metrics={
        'classification_output': ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    }
)

# %%
try:
    # Test a single dummy prediction to ensure the "Dual Output" works
    dummy_input = tf.random.uniform((1, 224, 224, 3))
    pred, feat = unified_model.predict(dummy_input)
    print(f"Prediction Output Shape: {pred.shape}") # Should be (1, 1)
    print(f"Feature Vector Shape: {feat.shape}")    # Should be (1, 256)
    print("\n✅ CHECKLIST PASSED: Architecture and Data are aligned.")
except Exception as e:
    print(f"\n❌ CHECKLIST FAILED: {e}")
# Out:
# 1/1 [==============================] - 9s 9s/step
# Prediction Output Shape: (1, 1)
# Feature Vector Shape: (1, 256)
#
# ✅ CHECKLIST PASSED: Architecture and Data are aligned.

# %%
# 1. Define the Optimizer
# Adam is used as it's highly efficient for transfer learning
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

# 2. Compile the Unified Model
unified_model.compile(
    optimizer=optimizer,
    # We define loss for the classification output only
    # The feature vector output is for extraction, not for direct optimization
    loss={
        'classification_output': 'binary_crossentropy',
        'asd_feature_vector': None 
    },
    # We track Accuracy, Precision, and Recall for the classification branch
    metrics={
        'classification_output': [
            'accuracy', 
            tf.keras.metrics.Precision(name='precision'), 
            tf.keras.metrics.Recall(name='recall')
        ]
    }
)

print("--- Step 3: Model Compilation Complete ---")
unified_model.summary()
# Out:
# --- Step 3: Model Compilation Complete ---
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  face_input (InputLayer)     [(None, 224, 224, 3)]     0
#
#  model_1 (Functional)        (None, 1, 1, 4096)        134260544
#
#  global_average_pooling2d (G  (None, 4096)             0
#  lobalAveragePooling2D)
#
#  asd_feature_vector (Dense)  (None, 256)               1048832
#
#  classification_output (Dens  (None, 1)                257
#  e)
#
# =================================================================
# Total params: 135,309,633
# Trainable params: 1,049,089
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %%
# Function to align dataset labels with the multi-output model architecture
def prepare_for_training(img, label):
    # We pass the same label to both output keys so the model knows where to look
    return img, {'classification_output': label, 'asd_feature_vector': label}

# Apply the mapping to all dataset splits
train_ds_final = train_ds.map(prepare_for_training)
val_ds_final = val_ds.map(prepare_for_training)
test_ds_final = test_ds.map(prepare_for_training)

print("Datasets are now configured for Dual-Output Training.")
# Out:
# Datasets are now configured for Dual-Output Training.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 1. Define Callbacks
# Stop if validation loss doesn't improve for 5 consecutive epochs
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=5, 
    restore_best_weights=True,
    verbose=1
)

# Save the best model weights based on highest validation accuracy
checkpoint_path = r"C:\Users\Yasindu\Desktop\Stuff\1.SLIIT\Research\Project\best_asd_model.h5"
checkpoint = ModelCheckpoint(
    checkpoint_path, 
    monitor='val_accuracy', 
    save_best_only=True, 
    mode='max',
    verbose=1
)

# 2. Start the Training Process
# We use 20 epochs, but EarlyStopping will likely halt it earlier if it peaks
print("Starting Training...")
history = unified_model.fit(
    train_ds_final,
    validation_data=val_ds_final,
    epochs=20,
    callbacks=[early_stop, checkpoint],
    verbose=1
)
# Out:
# Starting Training...
# Epoch 1/20
# 98/98 [==============================] - 55s 469ms/step - loss: 0.6810 - classification_output_loss: 0.6810 - classification_output_accuracy: 0.6621 - classification_output_precision: 0.6561 - classification_output_recall: 0.6849 - val_loss: 0.6651 - val_classification_output_loss: 0.6651 - val_classification_output_accuracy: 0.6842 - val_classification_output_precision: 0.7468 - val_classification_output_recall: 0.5693
# Epoch 2/20
# 98/98 [==============================] - 37s 379ms/step - loss: 0.6423 - classification_output_loss: 0.6423 - classification_output_accuracy: 0.7033 - classification_output_precision: 0.7324 - classification_output_recall: 0.6429 - val_loss: 0.6258 - val_classification_output_loss: 0.6258 - val_classification_output_accuracy: 0.6917 - val_classification_output_precision: 0.7453 - val_classification_output_recall: 0.5941
# Epoch 3/20
# 98/98 [==============================] - 37s 383ms/step - loss: 0.6015 - classification_output_loss: 0.6015 - classification_output_accuracy: 0.7230 - classification_output_precision: 0.7553 - classification_output_recall: 0.6620 - val_loss: 0.5908 - val_classification_output_loss: 0.5908 - val_classification_output_accuracy: 0.7293 - val_classification_output_precision: 0.7423 - val_classification_output_recall: 0.7129
# Epoch 4/20
# 98/98 [==============================] - 35s 362ms/step - loss: 0.5683 - classification_output_loss: 0.5683 - classification_output_accuracy: 0.7390 - classification_output_precision: 0.7620 - classification_output_recall: 0.6970 - val_loss: 0.5654 - val_classification_output_loss: 0.5654 - val_classification_output_accuracy: 0.7293 - val_classification_output_precision: 0.7554 - val_classification_output_recall: 0.6881
# Epoch 5/20
# 98/98 [==============================] - 36s 366ms/step - loss: 0.5421 - classification_output_loss: 0.5421 - classification_output_accuracy: 0.7521 - classification_output_precision: 0.7715 - classification_output_recall: 0.7180 - val_loss: 0.5433 - val_classification_output_loss: 0.5433 - val_classification_output_accuracy: 0.7419 - val_classification_output_precision: 0.7463 - val_classification_output_recall: 0.7426
# Epoch 6/20
# 98/98 [==============================] - 35s 361ms/step - loss: 0.5203 - classification_output_loss: 0.5203 - classification_output_accuracy: 0.7585 - classification_output_precision: 0.7710 - classification_output_recall: 0.7371 - val_loss: 0.5290 - val_classification_output_loss: 0.5290 - val_classification_output_accuracy: 0.7519 - val_classification_output_precision: 0.7754 - val_classification_output_recall: 0.7178
# Epoch 7/20
# 98/98 [==============================] - 37s 375ms/step - loss: 0.5025 - classification_output_loss: 0.5025 - classification_output_accuracy: 0.7696 - classification_output_precision: 0.7922 - classification_output_recall: 0.7327 - val_loss: 0.5162 - val_classification_output_loss: 0.5162 - val_classification_output_accuracy: 0.7569 - val_classification_output_precision: 0.7638 - val_classification_output_recall: 0.7525
# Epoch 8/20
# 98/98 [==============================] - 36s 370ms/step - loss: 0.4862 - classification_output_loss: 0.4862 - classification_output_accuracy: 0.7808 - classification_output_precision: 0.7966 - classification_output_recall: 0.7556 - val_loss: 0.5057 - val_classification_output_loss: 0.5057 - val_classification_output_accuracy: 0.7644 - val_classification_output_precision: 0.7700 - val_classification_output_recall: 0.7624
# Epoch 9/20
# 98/98 [==============================] - 35s 359ms/step - loss: 0.4722 - classification_output_loss: 0.4722 - classification_output_accuracy: 0.7904 - classification_output_precision: 0.8100 - classification_output_recall: 0.7600 - val_loss: 0.4972 - val_classification_output_loss: 0.4972 - val_classification_output_accuracy: 0.7694 - val_classification_output_precision: 0.7750 - val_classification_output_recall: 0.7673
# Epoch 10/20
# 98/98 [==============================] - 33s 338ms/step - loss: 0.4589 - classification_output_loss: 0.4589 - classification_output_accuracy: 0.7990 - classification_output_precision: 0.8135 - classification_output_recall: 0.7772 - val_loss: 0.4911 - val_classification_output_loss: 0.4911 - val_classification_output_accuracy: 0.7694 - val_classification_output_precision: 0.7989 - val_classification_output_recall: 0.7277
# Epoch 11/20
# 98/98 [==============================] - 641s 7s/step - loss: 0.4476 - classification_output_loss: 0.4476 - classification_output_accuracy: 0.8073 - classification_output_precision: 0.8260 - classification_output_recall: 0.7798 - val_loss: 0.4838 - val_classification_output_loss: 0.4838 - val_classification_output_accuracy: 0.7794 - val_classification_output_precision: 0.7850 - val_classification_output_recall: 0.7772
# Epoch 12/20
# 98/98 [==============================] - 30s 306ms/step - loss: 0.4363 - classification_output_loss: 0.4363 - classification_output_accuracy: 0.8114 - classification_output_precision: 0.8329 - classification_output_recall: 0.7804 - val_loss: 0.4782 - val_classification_output_loss: 0.4782 - val_classification_output_accuracy: 0.8020 - val_classification_output_precision: 0.7915 - val_classification_output_recall: 0.8267
# Epoch 13/20
# 98/98 [==============================] - 30s 303ms/step - loss: 0.4265 - classification_output_loss: 0.4265 - classification_output_accuracy: 0.8165 - classification_output_precision: 0.8268 - classification_output_recall: 0.8020 - val_loss: 0.4734 - val_classification_output_loss: 0.4734 - val_classification_output_accuracy: 0.8045 - val_classification_output_precision: 0.8039 - val_classification_output_recall: 0.8119
# Epoch 14/20
# 98/98 [==============================] - 32s 325ms/step - loss: 0.4169 - classification_output_loss: 0.4169 - classification_output_accuracy: 0.8220 - classification_output_precision: 0.8343 - classification_output_recall: 0.8046 - val_loss: 0.4705 - val_classification_output_loss: 0.4705 - val_classification_output_accuracy: 0.8020 - val_classification_output_precision: 0.7887 - val_classification_output_recall: 0.8317
# Epoch 15/20
# 98/98 [==============================] - 35s 354ms/step - loss: 0.4074 - classification_output_loss: 0.4074 - classification_output_accuracy: 0.8251 - classification_output_precision: 0.8394 - classification_output_recall: 0.8052 - val_loss: 0.4660 - val_classification_output_loss: 0.4660 - val_classification_output_accuracy: 0.8020 - val_classification_output_precision: 0.8000 - val_classification_output_recall: 0.8119
# Epoch 16/20
# 98/98 [==============================] - 35s 355ms/step - loss: 0.3988 - classification_output_loss: 0.3988 - classification_output_accuracy: 0.8325 - classification_output_precision: 0.8392 - classification_output_recall: 0.8237 - val_loss: 0.4636 - val_classification_output_loss: 0.4636 - val_classification_output_accuracy: 0.8045 - val_classification_output_precision: 0.8039 - val_classification_output_recall: 0.8119
# Epoch 17/20
# 98/98 [==============================] - 36s 370ms/step - loss: 0.3895 - classification_output_loss: 0.3895 - classification_output_accuracy: 0.8376 - classification_output_precision: 0.8439 - classification_output_recall: 0.8294 - val_loss: 0.4653 - val_classification_output_loss: 0.4653 - val_classification_output_accuracy: 0.7845 - val_classification_output_precision: 0.8118 - val_classification_output_recall: 0.7475
# Epoch 18/20
# 98/98 [==============================] - 35s 353ms/step - loss: 0.3826 - classification_output_loss: 0.3826 - classification_output_accuracy: 0.8411 - classification_output_precision: 0.8513 - classification_output_recall: 0.8275 - val_loss: 0.4597 - val_classification_output_loss: 0.4597 - val_classification_output_accuracy: 0.7945 - val_classification_output_precision: 0.8000 - val_classification_output_recall: 0.7921
# Epoch 19/20
# 98/98 [==============================] - 35s 357ms/step - loss: 0.3746 - classification_output_loss: 0.3746 - classification_output_accuracy: 0.8452 - classification_output_precision: 0.8512 - classification_output_recall: 0.8377 - val_loss: 0.4574 - val_classification_output_loss: 0.4574 - val_classification_output_accuracy: 0.7920 - val_classification_output_precision: 0.7990 - val_classification_output_recall: 0.7871
# Epoch 20/20
# 98/98 [==============================] - 35s 361ms/step - loss: 0.3669 - classification_output_loss: 0.3669 - classification_output_accuracy: 0.8500 - classification_output_precision: 0.8600 - classification_output_recall: 0.8370 - val_loss: 0.4552 - val_classification_output_loss: 0.4552 - val_classification_output_accuracy: 0.7895 - val_classification_output_precision: 0.7950 - val_classification_output_recall: 0.7871

# %%
print("Extending Training to 35 Epochs...")

history_extension = unified_model.fit(
    train_ds_final,
    validation_data=val_ds_final,
    epochs=15, # This adds 15 to your current 20
    callbacks=[early_stop, checkpoint]
)
# Out:
# Extending Training to 35 Epochs...
# Epoch 1/15
# 98/98 [==============================] - 35s 362ms/step - loss: 0.3596 - classification_output_loss: 0.3596 - classification_output_accuracy: 0.8532 - classification_output_precision: 0.8609 - classification_output_recall: 0.8434 - val_loss: 0.4525 - val_classification_output_loss: 0.4525 - val_classification_output_accuracy: 0.8045 - val_classification_output_precision: 0.8010 - val_classification_output_recall: 0.8168
# Epoch 2/15
# 98/98 [==============================] - 903s 9s/step - loss: 0.3525 - classification_output_loss: 0.3525 - classification_output_accuracy: 0.8580 - classification_output_precision: 0.8628 - classification_output_recall: 0.8523 - val_loss: 0.4522 - val_classification_output_loss: 0.4522 - val_classification_output_accuracy: 0.7945 - val_classification_output_precision: 0.8000 - val_classification_output_recall: 0.7921
# Epoch 3/15
# 98/98 [==============================] - 36s 369ms/step - loss: 0.3455 - classification_output_loss: 0.3455 - classification_output_accuracy: 0.8609 - classification_output_precision: 0.8673 - classification_output_recall: 0.8530 - val_loss: 0.4512 - val_classification_output_loss: 0.4512 - val_classification_output_accuracy: 0.7920 - val_classification_output_precision: 0.8020 - val_classification_output_recall: 0.7822
# Epoch 4/15
# 98/98 [==============================] - 37s 380ms/step - loss: 0.3388 - classification_output_loss: 0.3388 - classification_output_accuracy: 0.8660 - classification_output_precision: 0.8715 - classification_output_recall: 0.8593 - val_loss: 0.4514 - val_classification_output_loss: 0.4514 - val_classification_output_accuracy: 0.7920 - val_classification_output_precision: 0.8051 - val_classification_output_recall: 0.7772
# Epoch 5/15
# 98/98 [==============================] - 36s 372ms/step - loss: 0.3326 - classification_output_loss: 0.3326 - classification_output_accuracy: 0.8692 - classification_output_precision: 0.8797 - classification_output_recall: 0.8561 - val_loss: 0.4499 - val_classification_output_loss: 0.4499 - val_classification_output_accuracy: 0.7995 - val_classification_output_precision: 0.8020 - val_classification_output_recall: 0.8020
# Epoch 6/15
# 98/98 [==============================] - 34s 345ms/step - loss: 0.3259 - classification_output_loss: 0.3259 - classification_output_accuracy: 0.8752 - classification_output_precision: 0.8846 - classification_output_recall: 0.8638 - val_loss: 0.4480 - val_classification_output_loss: 0.4480 - val_classification_output_accuracy: 0.7995 - val_classification_output_precision: 0.7933 - val_classification_output_recall: 0.8168
# Epoch 7/15
# 98/98 [==============================] - 29s 294ms/step - loss: 0.3197 - classification_output_loss: 0.3197 - classification_output_accuracy: 0.8784 - classification_output_precision: 0.8819 - classification_output_recall: 0.8746 - val_loss: 0.4519 - val_classification_output_loss: 0.4519 - val_classification_output_accuracy: 0.7945 - val_classification_output_precision: 0.8158 - val_classification_output_recall: 0.7673
# Epoch 8/15
# 98/98 [==============================] - 29s 294ms/step - loss: 0.3137 - classification_output_loss: 0.3137 - classification_output_accuracy: 0.8810 - classification_output_precision: 0.8880 - classification_output_recall: 0.8727 - val_loss: 0.4501 - val_classification_output_loss: 0.4501 - val_classification_output_accuracy: 0.7970 - val_classification_output_precision: 0.8168 - val_classification_output_recall: 0.7723
# Epoch 9/15
# 98/98 [==============================] - 29s 299ms/step - loss: 0.3082 - classification_output_loss: 0.3082 - classification_output_accuracy: 0.8839 - classification_output_precision: 0.8968 - classification_output_recall: 0.8682 - val_loss: 0.4465 - val_classification_output_loss: 0.4465 - val_classification_output_accuracy: 0.7945 - val_classification_output_precision: 0.7857 - val_classification_output_recall: 0.8168
# Epoch 10/15
# 98/98 [==============================] - 29s 301ms/step - loss: 0.3023 - classification_output_loss: 0.3023 - classification_output_accuracy: 0.8874 - classification_output_precision: 0.8944 - classification_output_recall: 0.8791 - val_loss: 0.4459 - val_classification_output_loss: 0.4459 - val_classification_output_accuracy: 0.8045 - val_classification_output_precision: 0.8039 - val_classification_output_recall: 0.8119
# Epoch 11/15
# 98/98 [==============================] - 29s 295ms/step - loss: 0.2964 - classification_output_loss: 0.2964 - classification_output_accuracy: 0.8931 - classification_output_precision: 0.9018 - classification_output_recall: 0.8829 - val_loss: 0.4470 - val_classification_output_loss: 0.4470 - val_classification_output_accuracy: 0.8070 - val_classification_output_precision: 0.8079 - val_classification_output_recall: 0.8119
# Epoch 12/15
# 98/98 [==============================] - 29s 296ms/step - loss: 0.2909 - classification_output_loss: 0.2909 - classification_output_accuracy: 0.8944 - classification_output_precision: 0.9010 - classification_output_recall: 0.8867 - val_loss: 0.4489 - val_classification_output_loss: 0.4489 - val_classification_output_accuracy: 0.7995 - val_classification_output_precision: 0.8112 - val_classification_output_recall: 0.7871
# Epoch 13/15
# 98/98 [==============================] - 29s 297ms/step - loss: 0.2857 - classification_output_loss: 0.2857 - classification_output_accuracy: 0.8969 - classification_output_precision: 0.9073 - classification_output_recall: 0.8848 - val_loss: 0.4465 - val_classification_output_loss: 0.4465 - val_classification_output_accuracy: 0.8045 - val_classification_output_precision: 0.8069 - val_classification_output_recall: 0.8069
# Epoch 14/15
# 98/98 [==============================] - 29s 296ms/step - loss: 0.2803 - classification_output_loss: 0.2803 - classification_output_accuracy: 0.9008 - classification_output_precision: 0.9080 - classification_output_recall: 0.8924 - val_loss: 0.4489 - val_classification_output_loss: 0.4489 - val_classification_output_accuracy: 0.7945 - val_classification_output_precision: 0.8030 - val_classification_output_recall: 0.7871
# Epoch 15/15
# 98/98 [==============================] - ETA: 0s - loss: 0.2748 - classification_output_loss: 0.2748 - classification_output_accuracy: 0.9020 - classification_output_precision: 0.9120 - classification_output_recall: 0.8905Restoring model weights from the end of the best epoch: 10.
# 98/98 [==============================] - 29s 297ms/step - loss: 0.2748 - classification_output_loss: 0.2748 - classification_output_accuracy: 0.9020 - classification_output_precision: 0.9120 - classification_output_recall: 0.8905 - val_loss: 0.4475 - val_classification_output_loss: 0.4475 - val_classification_output_accuracy: 0.7995 - val_classification_output_precision: 0.7990 - val_classification_output_recall: 0.8069
# Epoch 15: early stopping

# %%
import tensorflow as tf
import gc

# --- STEP 1: CLEAR MEMORY ---
print("Cleaning up GPU memory...")
tf.keras.backend.clear_session()
gc.collect()

# --- STEP 2: RELOAD DATA WITH SMALLER BATCH SIZE (Fixes OOM) ---
# We reduce BATCH_SIZE from 32 to 8 to fit the gradients in VRAM
NEW_BATCH_SIZE = 8 

# Re-wrap your existing datasets with the new batch size
# Note: This assumes train_ds and val_ds are your original tf.data.Dataset objects
train_ds_low_mem = train_ds.unbatch().batch(NEW_BATCH_SIZE).map(prepare_for_training)
val_ds_low_mem = val_ds.unbatch().batch(NEW_BATCH_SIZE).map(prepare_for_training)

# --- STEP 3: PARTIAL UNFREEZING ---
# We unfreeze only the last block of VGG-Face (the high-level features)
feature_extractor.trainable = True

# Freeze everything EXCEPT the last 4 layers of the backbone
# This significantly reduces memory usage compared to unfreezing everything
for layer in feature_extractor.layers[:-4]:
    layer.trainable = False

print(f"Backbone unfrozen for final {len(feature_extractor.layers[-4:])} layers.")

# --- STEP 4: RE-COMPILE WITH ULTRA-LOW LEARNING RATE ---
# Use 1e-5 (0.00001) to delicately tune the pre-trained weights
unified_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss={'classification_output': 'binary_crossentropy'},
    metrics={'classification_output': ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]}
)

# --- STEP 5: RUN FINE-TUNING ---
print("Starting Phase 2: Specialist Fine-Tuning...")
history_fine = unified_model.fit(
    train_ds_low_mem,
    validation_data=val_ds_low_mem,
    epochs=10, 
    callbacks=[early_stop, checkpoint]
)
# Out:
# Cleaning up GPU memory...
# Backbone unfrozen for final 4 layers.
# Starting Phase 2: Specialist Fine-Tuning...
# Epoch 1/10
# 392/392 [==============================] - 72s 180ms/step - loss: 0.3103 - classification_output_loss: 0.3103 - classification_output_accuracy: 0.8679 - classification_output_precision: 0.8749 - classification_output_recall: 0.8593 - val_loss: 0.3785 - val_classification_output_loss: 0.3785 - val_classification_output_accuracy: 0.8471 - val_classification_output_precision: 0.8341 - val_classification_output_recall: 0.8713
# Epoch 2/10
# 392/392 [==============================] - 67s 172ms/step - loss: 0.0814 - classification_output_loss: 0.0814 - classification_output_accuracy: 0.9821 - classification_output_precision: 0.9871 - classification_output_recall: 0.9771 - val_loss: 0.4013 - val_classification_output_loss: 0.4013 - val_classification_output_accuracy: 0.8321 - val_classification_output_precision: 0.8610 - val_classification_output_recall: 0.7970
# Epoch 3/10
# 392/392 [==============================] - 69s 175ms/step - loss: 0.0283 - classification_output_loss: 0.0283 - classification_output_accuracy: 0.9968 - classification_output_precision: 0.9975 - classification_output_recall: 0.9962 - val_loss: 0.4704 - val_classification_output_loss: 0.4704 - val_classification_output_accuracy: 0.8471 - val_classification_output_precision: 0.9029 - val_classification_output_recall: 0.7822
# Epoch 4/10
# 392/392 [==============================] - 68s 174ms/step - loss: 0.0122 - classification_output_loss: 0.0122 - classification_output_accuracy: 0.9994 - classification_output_precision: 1.0000 - classification_output_recall: 0.9987 - val_loss: 0.4589 - val_classification_output_loss: 0.4589 - val_classification_output_accuracy: 0.8496 - val_classification_output_precision: 0.8318 - val_classification_output_recall: 0.8812
# Epoch 5/10
# 392/392 [==============================] - 65s 166ms/step - loss: 0.0044 - classification_output_loss: 0.0044 - classification_output_accuracy: 1.0000 - classification_output_precision: 1.0000 - classification_output_recall: 1.0000 - val_loss: 0.4834 - val_classification_output_loss: 0.4834 - val_classification_output_accuracy: 0.8496 - val_classification_output_precision: 0.8515 - val_classification_output_recall: 0.8515
# Epoch 6/10
# 392/392 [==============================] - ETA: 0s - loss: 0.0021 - classification_output_loss: 0.0021 - classification_output_accuracy: 1.0000 - classification_output_precision: 1.0000 - classification_output_recall: 1.0000Restoring model weights from the end of the best epoch: 1.
# 392/392 [==============================] - 65s 166ms/step - loss: 0.0021 - classification_output_loss: 0.0021 - classification_output_accuracy: 1.0000 - classification_output_precision: 1.0000 - classification_output_recall: 1.0000 - val_loss: 0.5102 - val_classification_output_loss: 0.5102 - val_classification_output_accuracy: 0.8521 - val_classification_output_precision: 0.8488 - val_classification_output_recall: 0.8614
# Epoch 6: early stopping

# %%
import tensorflow as tf
import gc
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 1. Clear GPU memory to make room
tf.keras.backend.clear_session()
gc.collect()

# 2. Re-batch the Test Dataset to a smaller size (8)
# This assumes 'test_ds' is your original test dataset variable
test_ds_low_mem = test_ds.unbatch().batch(8).map(prepare_for_training)

print("Evaluating on Test Dataset with low-memory configuration...")

# 3. Perform Evaluation
evaluation_results = unified_model.evaluate(test_ds_low_mem)
print(f"\nTest Accuracy: {evaluation_results[1]*100:.2f}%")
print(f"Test Precision: {evaluation_results[2]*100:.2f}%")
print(f"Test Recall: {evaluation_results[3]*100:.2f}%")

# 4. Get Predictions for the Confusion Matrix
y_true = []
y_pred = []

print("\nGenerating Confusion Matrix data...")
for images, labels in test_ds_low_mem:
    true_labels = labels['classification_output'].numpy().flatten()
    # We use verbose=0 to keep the console clean
    preds, _ = unified_model.predict(images, verbose=0)
    
    y_true.extend(true_labels)
    y_pred.extend((preds > 0.5).astype(int).flatten())

# 5. Visualize
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Non-Autistic', 'Autistic'], 
            yticklabels=['Non-Autistic', 'Autistic'])
plt.title('Final Confusion Matrix (Test Set)')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

print("\n--- Final Classification Report ---")
print(classification_report(y_true, y_pred, target_names=['Non-Autistic', 'Autistic']))
# Out:
# Evaluating on Test Dataset with low-memory configuration...
# 48/48 [==============================] - 6s 117ms/step - loss: 0.4460 - classification_output_loss: 0.4460 - classification_output_accuracy: 0.8125 - classification_output_precision: 0.7772 - classification_output_recall: 0.8533
#
# Test Accuracy: 44.60%
# Test Precision: 81.25%
# Test Recall: 77.72%
#
# Generating Confusion Matrix data...
# --- Final Classification Report ---
#               precision    recall  f1-score   support
#
# Non-Autistic       0.85      0.78      0.81       200
#     Autistic       0.78      0.85      0.81       184
#
#     accuracy                           0.81       384
#    macro avg       0.81      0.81      0.81       384
# weighted avg       0.82      0.81      0.81       384

# %%
from sklearn.manifold import TSNE
import pandas as pd

# 1. Extract features from the test set
print("Extracting feature vectors for visualization...")
all_features = []
all_labels = []

for images, labels in test_ds_low_mem:
    # Use the second output of our unified model
    _, features = unified_model.predict(images, verbose=0)
    all_features.append(features)
    all_labels.extend(labels['classification_output'].numpy().flatten())

all_features = np.concatenate(all_features, axis=0)
all_labels = np.array(all_labels)

# 2. Run t-SNE (Reduces 256D down to 2D for plotting)
tsne = TSNE(n_components=2, random_state=SEED)
low_dim_features = tsne.fit_transform(all_features)

# 3. Plot the Clusters
plt.figure(figsize=(10, 7))
df = pd.DataFrame({
    'x': low_dim_features[:, 0],
    'y': low_dim_features[:, 1],
    'Label': ['Autistic' if l == 1 else 'Non-Autistic' for l in all_labels]
})

sns.scatterplot(data=df, x='x', y='y', hue='Label', palette='viridis', alpha=0.7)
plt.title('t-SNE Visualization: How the Model Groups Facial Features')
plt.show()
# Out:
# Extracting feature vectors for visualization...

# %%
# Save the final model for deployment
model_save_path = r"C:\Users\Yasindu\Desktop\Stuff\1.SLIIT\Research\Project\models\model_3.h5"
unified_model.save(model_save_path)

print(f"Project Complete! Model saved to: {model_save_path}")
# Out:
# Project Complete! Model saved to: C:\Users\Yasindu\Desktop\Stuff\1.SLIIT\Research\Project\models\model_3.h5

# %%
# import tensorflow as tf
# import numpy as np
# import cv2
# import matplotlib.pyplot as plt

# def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
#     # 1. Create a model that maps the input image to the activations of the last conv layer
#     # and the output predictions
#     grad_model = tf.keras.models.Model(
#         [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output[0]]
#     )

#     # 2. Compute the gradient of the top predicted class for the input image
#     with tf.GradientTape() as tape:
#         last_conv_layer_output, preds = grad_model(img_array)
#         if pred_index is None:
#             pred_index = tf.argmax(preds[0])
#         class_channel = preds[:, pred_index]

#     # 3. This is the gradient of the output node with regard to the output feature map
#     grads = tape.gradient(class_channel, last_conv_layer_output)

#     # 4. Pool the gradients and weight the channels
#     pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
#     last_conv_layer_output = last_conv_layer_output[0]
#     heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
#     heatmap = tf.squeeze(heatmap)

#     # 5. Normalize the heatmap
#     heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
#     return heatmap.numpy()

# # Note: You need to find the name of the last conv layer in your VGG backbone
# # You can find it by running: unified_model.summary()
# # It is usually something like 'conv2d_12' or 'block5_conv3'

# %%
# # def display_gradcam(img_path, model, last_conv_layer_name):
#     # 1. Load the original image
#     img = image.load_img(img_path, target_size=(224, 224))
#     img_array = image.img_to_array(img)
#     img_batch = np.expand_dims(img_array, axis=0) / 255.0

#     # 2. Generate the heatmap using your function
#     heatmap = make_gradcam_heatmap(img_batch, model, last_conv_layer_name)

#     # 3. Use OpenCV to colorize and overlay
#     img_cv = cv2.imread(img_path)
#     img_cv = cv2.resize(img_cv, (224, 224))
    
#     # Rescale heatmap to 0-255
#     heatmap = np.uint8(255 * heatmap)
    
#     # Apply JET colormap (Blue = low importance, Red = high importance)
#     jet = plt.get_cmap("jet")
#     jet_colors = jet(np.arange(256))[:, :3]
#     jet_heatmap = jet_colors[heatmap]
    
#     # Create an image with RGB colorized heatmap
#     jet_heatmap = tf.keras.preprocessing.image.array_to_img(jet_heatmap)
#     jet_heatmap = jet_heatmap.resize((224, 224))
#     jet_heatmap = tf.keras.preprocessing.image.img_to_array(jet_heatmap)

#     # Superimpose the heatmap on original image
#     superimposed_img = jet_heatmap * 0.4 + img_cv  # 0.4 is the intensity of the heatmap
#     superimposed_img = tf.keras.preprocessing.image.array_to_img(superimposed_img)

#     # 4. Show the result
#     plt.figure(figsize=(10, 5))
#     plt.subplot(1, 2, 1)
#     plt.title("Original Image")
#     plt.imshow(cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB))
#     plt.axis('off')

#     plt.subplot(1, 2, 2)
#     plt.title("Grad-CAM (Where the AI looks)")
#     plt.imshow(superimposed_img)
#     plt.axis('off')
#     plt.show()

# # --- EXECUTE ---
# # Replace with a real path to one of your test images
# test_image_path = "path/to/your/test/image.jpg" 
# display_gradcam(test_image_path, unified_model, 'conv2d_12') # Update layer name!

# %%
import shutil
import os

# 1. Define destination
DEST_TEST_DIR = r"C:\Users\Yasindu\Desktop\Stuff\1.SLIIT\Research\Project\ModelTestingIMGS\model3"

# 2. Get the paths from the original remaining_ds before it was prefetched
# Since test_ds = remaining_ds.take(val_batches // 2)
all_paths = remaining_ds.file_paths
num_test_files = (val_batches // 2).numpy() * BATCH_SIZE 
# Note: we use the number of samples to slice the list of paths
test_paths = all_paths[:num_test_files]

print(f"Recovered {len(test_paths)} file paths.")
print(f"Starting copy...")

files_copied = 0
for path in test_paths:
    class_name = os.path.basename(os.path.dirname(path))
    target_dir = os.path.join(DEST_TEST_DIR, class_name)
    
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
    
    shutil.copy(path, os.path.join(target_dir, os.path.basename(path)))
    files_copied += 1

print(f"\n✅ SUCCESS! Copied {files_copied} images to {DEST_TEST_DIR}")
# Out:
# Recovered 384 file paths.
# Starting copy...
#
# ✅ SUCCESS! Copied 384 images to C:\Users\Yasindu\Desktop\Stuff\1.SLIIT\Research\Project\ModelTestingIMGS\model3
