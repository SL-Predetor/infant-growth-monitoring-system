# %%
import sys
import importlib.metadata
import tensorflow as tf
import os
import gc
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from deepface import DeepFace
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE

# %%
if tf.config.list_physical_devices('GPU'):
    print("GPU is available.")
    physical_devices = tf.config.list_physical_devices('GPU')
    for device in physical_devices:
        print(f"Device: {device}")
        from tensorflow.python.client import device_lib
        local_device_protos = device_lib.list_local_devices()
        for device in local_device_protos:
            if device.device_type == 'GPU':
                print(f"Name: {device.name}")
                print(f"Memory Limit: {device.memory_limit / 1024 / 1024} MB")
else:
    print("No GPU available.")
# Out:
# GPU is available.
# Device: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Name: /device:GPU:0
# Memory Limit: 3501.0 MB

# %%
packages = ["deepface", "opencv-python", "numpy", "matplotlib", 
            "scikit-learn", "tensorflow", "pandas", "seaborn"]

print(f"Python version: {sys.version}")

for pkg in packages:
    try:
        version = importlib.metadata.version(pkg)
        print(f"{pkg}: {version}")
    except importlib.metadata.PackageNotFoundError:
        print(f"{pkg}: Not found")
# Out:
# Python version: 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]
# deepface: 0.0.96
# opencv-python: 4.6.0.66
# numpy: 1.23.5
# matplotlib: 3.10.8
# scikit-learn: 1.7.2
# tensorflow: 2.10.0
# pandas: 2.3.3
# seaborn: 0.13.2

# %%
DATA_DIR = r"C:\Users\Yasindu\Desktop\Stuff\1.SLIIT\Research\Project\data\imgData\prepImg\step4"

# %%
IMG_SIZE = (224, 224) 
BATCH_SIZE = 32
SEED = 123

# %%
# --- 2. Load the Dataset ---
# 80% Training
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary'
)

# 20% for Val and Test
remaining_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary'
)

# Final split for 10% Test / 10% Val
val_batches = tf.data.experimental.cardinality(remaining_ds)
test_ds = remaining_ds.take(val_batches // 2)
val_ds = remaining_ds.skip(val_batches // 2)
# Out:
# Found 3917 files belonging to 2 classes.
# Using 3134 files for training.
# Found 3917 files belonging to 2 classes.
# Using 783 files for validation.

# %%
# --- 3. Combined Preprocessing (Normalization + Label Flip) ---
normalization_layer = tf.keras.layers.Rescaling(1./255)

def preprocess(x, y):
    # Normalize pixels to [0, 1]
    x = normalization_layer(x)
    # Flip labels so Autistic (alphabetically first, so 0) becomes 1
    y = 1 - y
    return x, y

train_ds = train_ds.map(preprocess)
val_ds = val_ds.map(preprocess)
test_ds = test_ds.map(preprocess)

# --- 4. Performance Optimization ---
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

print("\n--- Data Preparation Complete ---")
print("Confirmed: Autistic is now labeled 1, Non_Autistic is labeled 0.")
# Out:
# --- Data Preparation Complete ---
# Confirmed: Autistic is now labeled 1, Non_Autistic is labeled 0.

# %%
for images, labels in train_ds.take(1):
    print(f"Sample Batch Labels: {labels.numpy().flatten()[:5]}")
    print(f"Pixel Max: {tf.reduce_max(images).numpy()}")
# Out:
# Sample Batch Labels: [0. 1. 1. 1. 1.]
# Pixel Max: 1.0

# %%
# --- 1. Load the Pre-trained Backbone ---
vgg_model_wrapper = DeepFace.build_model("VGG-Face")
full_vgg_face = vgg_model_wrapper.model 

vgg_model_wrapper = DeepFace.build_model("VGG-Face")
full_vgg_face = vgg_model_wrapper.model 

# --- 2. Strip away the recognition layers ---
# Based on your error log, 'conv2d_14' is the final feature-rich layer.
backbone_output = full_vgg_face.get_layer("conv2d_14").output
feature_extractor = Model(inputs=full_vgg_face.input, outputs=backbone_output)

# --- 3. Freeze the Backbone Layers ---
feature_extractor.trainable = False

# --- 4. Attach the Custom Head ---
inputs = Input(shape=(224, 224, 3), name="face_input")

# %%
# Pass input through frozen backbone
# training=False is critical to keep the model in inference mode
x = feature_extractor(inputs, training=False)

# A. Global Average Pooling 
# This converts the 2D output of conv2d_14 into a 1D vector
x = GlobalAveragePooling2D()(x)

# B. Dense Layer (ASD Feature Learner)
feature_layer = Dense(256, activation='relu', name='asd_feature_vector')(x)

# C. Output Layer (Sigmoid for binary probability)
prediction = Dense(1, activation='sigmoid', name='classification_output')(feature_layer)

# --- 5. Build the Unified Model ---
# This meets your requirement for dual outputs (prediction + feature vector)
unified_model = Model(inputs=inputs, outputs=[prediction, feature_layer])

# Verify
unified_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  face_input (InputLayer)     [(None, 224, 224, 3)]     0
#
#  model_1 (Functional)        (None, 1, 1, 4096)        134260544
#
#  global_average_pooling2d (G  (None, 4096)             0
#  lobalAveragePooling2D)
#
#  asd_feature_vector (Dense)  (None, 256)               1048832
#
#  classification_output (Dens  (None, 1)                257
#  e)
#
# =================================================================
# Total params: 135,309,633
# Trainable params: 1,049,089
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %%
# Adjust datasets to handle the dual-output architecture
def map_for_dual_output(img, label):
    # The first 'label' is for classification_output
    # The second 'None' tells Keras not to calculate loss for the feature_vector output
    return img, {'classification_output': label, 'asd_feature_vector': label}

train_ds_final = train_ds.map(map_for_dual_output)
val_ds_final = val_ds.map(map_for_dual_output)
test_ds_final = test_ds.map(map_for_dual_output)

# %%
# Adjust datasets to handle the dual-output architecture
def map_for_dual_output(img, label):
    # The first 'label' is for classification_output
    # The second 'None' tells Keras not to calculate loss for the feature_vector output
    return img, {'classification_output': label, 'asd_feature_vector': label}

train_ds_final = train_ds.map(map_for_dual_output)
val_ds_final = val_ds.map(map_for_dual_output)
test_ds_final = test_ds.map(map_for_dual_output)

# %%
try:
    # Test a single dummy prediction to ensure the "Dual Output" works
    dummy_input = tf.random.uniform((1, 224, 224, 3))
    pred, feat = unified_model.predict(dummy_input)
    print(f"Prediction Output Shape: {pred.shape}") # Should be (1, 1)
    print(f"Feature Vector Shape: {feat.shape}")    # Should be (1, 256)
    print("\n✅ CHECKLIST PASSED: Architecture and Data are aligned.")
except Exception as e:
    print(f"\n❌ CHECKLIST FAILED: {e}")
# Out:
# 1/1 [==============================] - 5s 5s/step
# Prediction Output Shape: (1, 1)
# Feature Vector Shape: (1, 256)
#
# ✅ CHECKLIST PASSED: Architecture and Data are aligned.

# %%
# 1. Define the Optimizer
# Adam is used as it's highly efficient for transfer learning
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

# 2. Compile the Unified Model
unified_model.compile(
    optimizer=optimizer,
    # We define loss for the classification output only
    # The feature vector output is for extraction, not for direct optimization
    loss={
        'classification_output': 'binary_crossentropy',
        'asd_feature_vector': None 
    },
    # We track Accuracy, Precision, and Recall for the classification branch
    metrics={
        'classification_output': [
            'accuracy', 
            tf.keras.metrics.Precision(name='precision'), 
            tf.keras.metrics.Recall(name='recall')
        ]
    }
)

print("--- Step 3: Model Compilation Complete ---")
unified_model.summary()
# Out:
# --- Step 3: Model Compilation Complete ---
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  face_input (InputLayer)     [(None, 224, 224, 3)]     0
#
#  model_1 (Functional)        (None, 1, 1, 4096)        134260544
#
#  global_average_pooling2d (G  (None, 4096)             0
#  lobalAveragePooling2D)
#
#  asd_feature_vector (Dense)  (None, 256)               1048832
#
#  classification_output (Dens  (None, 1)                257
#  e)
#
# =================================================================
# Total params: 135,309,633
# Trainable params: 1,049,089
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %%
# Function to align dataset labels with the multi-output model architecture
def prepare_for_training(img, label):
    # We pass the same label to both output keys so the model knows where to look
    return img, {'classification_output': label, 'asd_feature_vector': label}

# Apply the mapping to all dataset splits
train_ds_final = train_ds.map(prepare_for_training)
val_ds_final = val_ds.map(prepare_for_training)
test_ds_final = test_ds.map(prepare_for_training)

print("Datasets are now configured for Dual-Output Training.")
# Out:
# Datasets are now configured for Dual-Output Training.

# %%
# 1. Define Callbacks
# Stop if validation loss doesn't improve for 5 consecutive epochs
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=5, 
    restore_best_weights=True,
    verbose=1
)

# %%
# Save the best model weights based on highest validation accuracy
checkpoint_path = r"C:\Users\Yasindu\Desktop\Stuff\1.SLIIT\Research\Project\best_asd_model4.h5"
checkpoint = ModelCheckpoint(
    checkpoint_path, 
    monitor='val_accuracy', 
    save_best_only=True, 
    mode='max',
    verbose=1
)

# %%
# 2. Start the Training Process
# We use 20 epochs
print("Starting Training...")
history = unified_model.fit(
    train_ds_final,
    validation_data=val_ds_final,
    epochs=20,
    callbacks=[early_stop, checkpoint],
    verbose=1
)
# Out:
# Starting Training...
# Epoch 1/20
# 98/98 [==============================] - 55s 481ms/step - loss: 0.6794 - classification_output_loss: 0.6794 - classification_output_accuracy: 0.6248 - classification_output_precision: 0.7644 - classification_output_recall: 0.3635 - val_loss: 0.6620 - val_classification_output_loss: 0.6620 - val_classification_output_accuracy: 0.6992 - val_classification_output_precision: 0.7440 - val_classification_output_recall: 0.6188
# Epoch 2/20
# 98/98 [==============================] - 38s 392ms/step - loss: 0.6387 - classification_output_loss: 0.6387 - classification_output_accuracy: 0.7100 - classification_output_precision: 0.7531 - classification_output_recall: 0.6270 - val_loss: 0.6201 - val_classification_output_loss: 0.6201 - val_classification_output_accuracy: 0.7243 - val_classification_output_precision: 0.7347 - val_classification_output_recall: 0.7129
# Epoch 3/20
# 98/98 [==============================] - 37s 382ms/step - loss: 0.5968 - classification_output_loss: 0.5968 - classification_output_accuracy: 0.7313 - classification_output_precision: 0.7481 - classification_output_recall: 0.6996 - val_loss: 0.5875 - val_classification_output_loss: 0.5875 - val_classification_output_accuracy: 0.7093 - val_classification_output_precision: 0.7500 - val_classification_output_recall: 0.6386
# Epoch 4/20
# 98/98 [==============================] - 49s 501ms/step - loss: 0.5639 - classification_output_loss: 0.5639 - classification_output_accuracy: 0.7358 - classification_output_precision: 0.7578 - classification_output_recall: 0.6951 - val_loss: 0.5603 - val_classification_output_loss: 0.5603 - val_classification_output_accuracy: 0.7419 - val_classification_output_precision: 0.7565 - val_classification_output_recall: 0.7228
# Epoch 5/20
# 98/98 [==============================] - 44s 453ms/step - loss: 0.5379 - classification_output_loss: 0.5379 - classification_output_accuracy: 0.7508 - classification_output_precision: 0.7687 - classification_output_recall: 0.7193 - val_loss: 0.5412 - val_classification_output_loss: 0.5412 - val_classification_output_accuracy: 0.7419 - val_classification_output_precision: 0.7735 - val_classification_output_recall: 0.6931
# Epoch 6/20
# 98/98 [==============================] - 41s 421ms/step - loss: 0.5163 - classification_output_loss: 0.5163 - classification_output_accuracy: 0.7623 - classification_output_precision: 0.7761 - classification_output_recall: 0.7390 - val_loss: 0.5274 - val_classification_output_loss: 0.5274 - val_classification_output_accuracy: 0.7519 - val_classification_output_precision: 0.7877 - val_classification_output_recall: 0.6980
# Epoch 7/20
# 98/98 [==============================] - 39s 396ms/step - loss: 0.4992 - classification_output_loss: 0.4992 - classification_output_accuracy: 0.7690 - classification_output_precision: 0.7939 - classification_output_recall: 0.7282 - val_loss: 0.5137 - val_classification_output_loss: 0.5137 - val_classification_output_accuracy: 0.7594 - val_classification_output_precision: 0.7849 - val_classification_output_recall: 0.7228
# Epoch 8/20
# 98/98 [==============================] - 39s 397ms/step - loss: 0.4829 - classification_output_loss: 0.4829 - classification_output_accuracy: 0.7824 - classification_output_precision: 0.7938 - classification_output_recall: 0.7645 - val_loss: 0.5044 - val_classification_output_loss: 0.5044 - val_classification_output_accuracy: 0.7519 - val_classification_output_precision: 0.7725 - val_classification_output_recall: 0.7228
# Epoch 9/20
# 98/98 [==============================] - 39s 401ms/step - loss: 0.4690 - classification_output_loss: 0.4690 - classification_output_accuracy: 0.7958 - classification_output_precision: 0.8110 - classification_output_recall: 0.7728 - val_loss: 0.4964 - val_classification_output_loss: 0.4964 - val_classification_output_accuracy: 0.7644 - val_classification_output_precision: 0.7872 - val_classification_output_recall: 0.7327
# Epoch 10/20
# 98/98 [==============================] - 39s 402ms/step - loss: 0.4568 - classification_output_loss: 0.4568 - classification_output_accuracy: 0.8022 - classification_output_precision: 0.8168 - classification_output_recall: 0.7804 - val_loss: 0.4883 - val_classification_output_loss: 0.4883 - val_classification_output_accuracy: 0.7719 - val_classification_output_precision: 0.7876 - val_classification_output_recall: 0.7525
# Epoch 11/20
# 98/98 [==============================] - 41s 417ms/step - loss: 0.4452 - classification_output_loss: 0.4452 - classification_output_accuracy: 0.8070 - classification_output_precision: 0.8264 - classification_output_recall: 0.7785 - val_loss: 0.4826 - val_classification_output_loss: 0.4826 - val_classification_output_accuracy: 0.7845 - val_classification_output_precision: 0.7929 - val_classification_output_recall: 0.7772
# Epoch 12/20
# 98/98 [==============================] - 39s 395ms/step - loss: 0.4339 - classification_output_loss: 0.4339 - classification_output_accuracy: 0.8130 - classification_output_precision: 0.8290 - classification_output_recall: 0.7899 - val_loss: 0.4768 - val_classification_output_loss: 0.4768 - val_classification_output_accuracy: 0.7970 - val_classification_output_precision: 0.7923 - val_classification_output_recall: 0.8119
# Epoch 13/20
# 98/98 [==============================] - 37s 377ms/step - loss: 0.4237 - classification_output_loss: 0.4237 - classification_output_accuracy: 0.8204 - classification_output_precision: 0.8320 - classification_output_recall: 0.8039 - val_loss: 0.4738 - val_classification_output_loss: 0.4738 - val_classification_output_accuracy: 0.7945 - val_classification_output_precision: 0.8030 - val_classification_output_recall: 0.7871
# Epoch 14/20
# 98/98 [==============================] - 41s 425ms/step - loss: 0.4144 - classification_output_loss: 0.4144 - classification_output_accuracy: 0.8229 - classification_output_precision: 0.8400 - classification_output_recall: 0.7989 - val_loss: 0.4692 - val_classification_output_loss: 0.4692 - val_classification_output_accuracy: 0.8045 - val_classification_output_precision: 0.7897 - val_classification_output_recall: 0.8366
# Epoch 15/20
# 98/98 [==============================] - 38s 394ms/step - loss: 0.4048 - classification_output_loss: 0.4048 - classification_output_accuracy: 0.8309 - classification_output_precision: 0.8365 - classification_output_recall: 0.8237 - val_loss: 0.4654 - val_classification_output_loss: 0.4654 - val_classification_output_accuracy: 0.7995 - val_classification_output_precision: 0.8050 - val_classification_output_recall: 0.7970
# Epoch 16/20
# 98/98 [==============================] - 40s 406ms/step - loss: 0.3965 - classification_output_loss: 0.3965 - classification_output_accuracy: 0.8338 - classification_output_precision: 0.8449 - classification_output_recall: 0.8186 - val_loss: 0.4628 - val_classification_output_loss: 0.4628 - val_classification_output_accuracy: 0.7945 - val_classification_output_precision: 0.8000 - val_classification_output_recall: 0.7921
# Epoch 17/20
# 98/98 [==============================] - 40s 406ms/step - loss: 0.3879 - classification_output_loss: 0.3879 - classification_output_accuracy: 0.8360 - classification_output_precision: 0.8452 - classification_output_recall: 0.8237 - val_loss: 0.4593 - val_classification_output_loss: 0.4593 - val_classification_output_accuracy: 0.8020 - val_classification_output_precision: 0.8030 - val_classification_output_recall: 0.8069
# Epoch 18/20
# 98/98 [==============================] - 39s 395ms/step - loss: 0.3798 - classification_output_loss: 0.3798 - classification_output_accuracy: 0.8414 - classification_output_precision: 0.8514 - classification_output_recall: 0.8281 - val_loss: 0.4577 - val_classification_output_loss: 0.4577 - val_classification_output_accuracy: 0.8095 - val_classification_output_precision: 0.8000 - val_classification_output_recall: 0.8317
# Epoch 19/20
# 98/98 [==============================] - 36s 372ms/step - loss: 0.3722 - classification_output_loss: 0.3722 - classification_output_accuracy: 0.8443 - classification_output_precision: 0.8500 - classification_output_recall: 0.8370 - val_loss: 0.4561 - val_classification_output_loss: 0.4561 - val_classification_output_accuracy: 0.7920 - val_classification_output_precision: 0.7990 - val_classification_output_recall: 0.7871
# Epoch 20/20
# 98/98 [==============================] - 39s 397ms/step - loss: 0.3648 - classification_output_loss: 0.3648 - classification_output_accuracy: 0.8494 - classification_output_precision: 0.8561 - classification_output_recall: 0.8409 - val_loss: 0.4535 - val_classification_output_loss: 0.4535 - val_classification_output_accuracy: 0.7995 - val_classification_output_precision: 0.8020 - val_classification_output_recall: 0.8020

# %%
print("Extending Training to 35 Epochs...")

history_extension = unified_model.fit(
    train_ds_final,
    validation_data=val_ds_final,
    epochs=15, # This adds 15 to your current 20
    callbacks=[early_stop, checkpoint]
)
# Out:
# Extending Training to 35 Epochs...
# Epoch 1/15
# 98/98 [==============================] - 30s 303ms/step - loss: 0.3572 - classification_output_loss: 0.3572 - classification_output_accuracy: 0.8523 - classification_output_precision: 0.8616 - classification_output_recall: 0.8402 - val_loss: 0.4525 - val_classification_output_loss: 0.4525 - val_classification_output_accuracy: 0.8095 - val_classification_output_precision: 0.8029 - val_classification_output_recall: 0.8267
# Epoch 2/15
# 98/98 [==============================] - 32s 327ms/step - loss: 0.3496 - classification_output_loss: 0.3496 - classification_output_accuracy: 0.8602 - classification_output_precision: 0.8629 - classification_output_recall: 0.8574 - val_loss: 0.4529 - val_classification_output_loss: 0.4529 - val_classification_output_accuracy: 0.7845 - val_classification_output_precision: 0.7990 - val_classification_output_recall: 0.7673
# Epoch 3/15
# 98/98 [==============================] - 38s 392ms/step - loss: 0.3432 - classification_output_loss: 0.3432 - classification_output_accuracy: 0.8609 - classification_output_precision: 0.8697 - classification_output_recall: 0.8498 - val_loss: 0.4486 - val_classification_output_loss: 0.4486 - val_classification_output_accuracy: 0.8070 - val_classification_output_precision: 0.8049 - val_classification_output_recall: 0.8168
# Epoch 4/15
# 98/98 [==============================] - 37s 382ms/step - loss: 0.3364 - classification_output_loss: 0.3364 - classification_output_accuracy: 0.8695 - classification_output_precision: 0.8753 - classification_output_recall: 0.8625 - val_loss: 0.4484 - val_classification_output_loss: 0.4484 - val_classification_output_accuracy: 0.8020 - val_classification_output_precision: 0.7971 - val_classification_output_recall: 0.8168
# Epoch 5/15
# 98/98 [==============================] - 39s 397ms/step - loss: 0.3299 - classification_output_loss: 0.3299 - classification_output_accuracy: 0.8698 - classification_output_precision: 0.8749 - classification_output_recall: 0.8638 - val_loss: 0.4478 - val_classification_output_loss: 0.4478 - val_classification_output_accuracy: 0.8020 - val_classification_output_precision: 0.8000 - val_classification_output_recall: 0.8119
# Epoch 6/15
# 98/98 [==============================] - 38s 387ms/step - loss: 0.3241 - classification_output_loss: 0.3241 - classification_output_accuracy: 0.8759 - classification_output_precision: 0.8803 - classification_output_recall: 0.8708 - val_loss: 0.4476 - val_classification_output_loss: 0.4476 - val_classification_output_accuracy: 0.8045 - val_classification_output_precision: 0.8069 - val_classification_output_recall: 0.8069
# Epoch 7/15
# 98/98 [==============================] - 38s 391ms/step - loss: 0.3174 - classification_output_loss: 0.3174 - classification_output_accuracy: 0.8772 - classification_output_precision: 0.8876 - classification_output_recall: 0.8644 - val_loss: 0.4483 - val_classification_output_loss: 0.4483 - val_classification_output_accuracy: 0.7895 - val_classification_output_precision: 0.7757 - val_classification_output_recall: 0.8218
# Epoch 8/15
# 98/98 [==============================] - 38s 388ms/step - loss: 0.3114 - classification_output_loss: 0.3114 - classification_output_accuracy: 0.8842 - classification_output_precision: 0.8907 - classification_output_recall: 0.8765 - val_loss: 0.4473 - val_classification_output_loss: 0.4473 - val_classification_output_accuracy: 0.8045 - val_classification_output_precision: 0.8069 - val_classification_output_recall: 0.8069
# Epoch 9/15
# 98/98 [==============================] - 37s 378ms/step - loss: 0.3053 - classification_output_loss: 0.3053 - classification_output_accuracy: 0.8861 - classification_output_precision: 0.8926 - classification_output_recall: 0.8784 - val_loss: 0.4464 - val_classification_output_loss: 0.4464 - val_classification_output_accuracy: 0.8070 - val_classification_output_precision: 0.8079 - val_classification_output_recall: 0.8119
# Epoch 10/15
# 98/98 [==============================] - 36s 364ms/step - loss: 0.2995 - classification_output_loss: 0.2995 - classification_output_accuracy: 0.8896 - classification_output_precision: 0.8995 - classification_output_recall: 0.8778 - val_loss: 0.4460 - val_classification_output_loss: 0.4460 - val_classification_output_accuracy: 0.8020 - val_classification_output_precision: 0.8030 - val_classification_output_recall: 0.8069
# Epoch 11/15
# 98/98 [==============================] - 35s 359ms/step - loss: 0.2942 - classification_output_loss: 0.2942 - classification_output_accuracy: 0.8941 - classification_output_precision: 0.8979 - classification_output_recall: 0.8899 - val_loss: 0.4482 - val_classification_output_loss: 0.4482 - val_classification_output_accuracy: 0.7995 - val_classification_output_precision: 0.8144 - val_classification_output_recall: 0.7822
# Epoch 12/15
# 98/98 [==============================] - 35s 360ms/step - loss: 0.2886 - classification_output_loss: 0.2886 - classification_output_accuracy: 0.8950 - classification_output_precision: 0.9059 - classification_output_recall: 0.8822 - val_loss: 0.4485 - val_classification_output_loss: 0.4485 - val_classification_output_accuracy: 0.7995 - val_classification_output_precision: 0.8144 - val_classification_output_recall: 0.7822
# Epoch 13/15
# 98/98 [==============================] - 35s 361ms/step - loss: 0.2827 - classification_output_loss: 0.2827 - classification_output_accuracy: 0.8995 - classification_output_precision: 0.9083 - classification_output_recall: 0.8892 - val_loss: 0.4460 - val_classification_output_loss: 0.4460 - val_classification_output_accuracy: 0.8045 - val_classification_output_precision: 0.8069 - val_classification_output_recall: 0.8069
# Epoch 14/15
# 98/98 [==============================] - 35s 357ms/step - loss: 0.2778 - classification_output_loss: 0.2778 - classification_output_accuracy: 0.9020 - classification_output_precision: 0.9088 - classification_output_recall: 0.8943 - val_loss: 0.4462 - val_classification_output_loss: 0.4462 - val_classification_output_accuracy: 0.7970 - val_classification_output_precision: 0.7951 - val_classification_output_recall: 0.8069
# Epoch 15/15
# 98/98 [==============================] - 35s 356ms/step - loss: 0.2724 - classification_output_loss: 0.2724 - classification_output_accuracy: 0.9059 - classification_output_precision: 0.9148 - classification_output_recall: 0.8956 - val_loss: 0.4468 - val_classification_output_loss: 0.4468 - val_classification_output_accuracy: 0.8020 - val_classification_output_precision: 0.8060 - val_classification_output_recall: 0.8020

# %%
print("Cleaning up GPU memory...")
tf.keras.backend.clear_session()
gc.collect()
# Out:
# Cleaning up GPU memory...
# 2299

# %%
NEW_BATCH_SIZE = 16

# %%
train_ds_low_mem = train_ds.unbatch().batch(NEW_BATCH_SIZE).map(prepare_for_training)
val_ds_low_mem = val_ds.unbatch().batch(NEW_BATCH_SIZE).map(prepare_for_training)

# %%
# --- STEP 3: PARTIAL UNFREEZING ---
# We unfreeze only the last block of VGG-Face (the high-level features)
feature_extractor.trainable = True

# Freeze everything EXCEPT the last 4 layers of the backbone
for layer in feature_extractor.layers[:-4]:
    layer.trainable = False

print(f"Backbone unfrozen for final {len(feature_extractor.layers[-4:])} layers.")
# Out:
# Backbone unfrozen for final 4 layers.

# %%
# --- STEP 4: RE-COMPILE WITH ULTRA-LOW LEARNING RATE ---
# Use 1e-5 (0.00001) to delicately tune the pre-trained weights
unified_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss={'classification_output': 'binary_crossentropy'},
    metrics={'classification_output': ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]}
)

# %%
# --- STEP 5: RUN FINE-TUNING ---
print("Starting Phase 2: Specialist Fine-Tuning...")
history_fine = unified_model.fit(
    train_ds_low_mem,
    validation_data=val_ds_low_mem,
    epochs=10, 
    callbacks=[early_stop, checkpoint]
)
# Out:
# Starting Phase 2: Specialist Fine-Tuning...
# Epoch 1/10
# 196/196 [==============================] - 59s 273ms/step - loss: 0.2734 - classification_output_loss: 0.2734 - classification_output_accuracy: 0.8854 - classification_output_precision: 0.8885 - classification_output_recall: 0.8822 - val_loss: 0.4295 - val_classification_output_loss: 0.4295 - val_classification_output_accuracy: 0.8346 - val_classification_output_precision: 0.8778 - val_classification_output_recall: 0.7822
# Epoch 2/10
# 196/196 [==============================] - 51s 259ms/step - loss: 0.0782 - classification_output_loss: 0.0782 - classification_output_accuracy: 0.9856 - classification_output_precision: 0.9904 - classification_output_recall: 0.9809 - val_loss: 0.3896 - val_classification_output_loss: 0.3896 - val_classification_output_accuracy: 0.8471 - val_classification_output_precision: 0.8579 - val_classification_output_recall: 0.8366
# Epoch 3/10
# 196/196 [==============================] - 50s 253ms/step - loss: 0.0324 - classification_output_loss: 0.0324 - classification_output_accuracy: 0.9974 - classification_output_precision: 0.9994 - classification_output_recall: 0.9955 - val_loss: 0.4286 - val_classification_output_loss: 0.4286 - val_classification_output_accuracy: 0.8446 - val_classification_output_precision: 0.8646 - val_classification_output_recall: 0.8218
# Epoch 4/10
# 196/196 [==============================] - 50s 257ms/step - loss: 0.0140 - classification_output_loss: 0.0140 - classification_output_accuracy: 0.9997 - classification_output_precision: 1.0000 - classification_output_recall: 0.9994 - val_loss: 0.4505 - val_classification_output_loss: 0.4505 - val_classification_output_accuracy: 0.8421 - val_classification_output_precision: 0.8528 - val_classification_output_recall: 0.8317
# Epoch 5/10
# 196/196 [==============================] - 51s 260ms/step - loss: 0.0065 - classification_output_loss: 0.0065 - classification_output_accuracy: 1.0000 - classification_output_precision: 1.0000 - classification_output_recall: 1.0000 - val_loss: 0.4757 - val_classification_output_loss: 0.4757 - val_classification_output_accuracy: 0.8496 - val_classification_output_precision: 0.8660 - val_classification_output_recall: 0.8317
# Epoch 6/10
# 182/196 [==========================>...] - ETA: 3s - loss: 0.0039 - classification_output_loss: 0.0039 - classification_output_accuracy: 1.0000 - classification_output_precision: 1.0000 - classification_output_recall: 1.0000

# %%
tf.keras.backend.clear_session()
gc.collect()

# %%
# 2. Re-batch the Test Dataset to a smaller size (8)
test_ds_low_mem = test_ds.unbatch().batch(8).map(prepare_for_training)

print("Evaluating on Test Dataset with low-memory configuration...")

# %%
# 3. Perform Evaluation
evaluation_results = unified_model.evaluate(test_ds_low_mem)
print(f"\nTest Accuracy: {evaluation_results[1]*100:.2f}%")
print(f"Test Precision: {evaluation_results[2]*100:.2f}%")
print(f"Test Recall: {evaluation_results[3]*100:.2f}%")

# 4. Get Predictions for the Confusion Matrix
y_true = []
y_pred = []

print("\nGenerating Confusion Matrix data...")
for images, labels in test_ds_low_mem:
    true_labels = labels['classification_output'].numpy().flatten()
    # We use verbose=0 to keep the console clean
    preds, _ = unified_model.predict(images, verbose=0)
    
    y_true.extend(true_labels)
    y_pred.extend((preds > 0.5).astype(int).flatten())

# 5. Visualize
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Non-Autistic', 'Autistic'], 
            yticklabels=['Non-Autistic', 'Autistic'])
plt.title('Final Confusion Matrix (Test Set)')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

print("\n--- Final Classification Report ---")
print(classification_report(y_true, y_pred, target_names=['Non-Autistic', 'Autistic']))

# %%
# 1. Extract features from the test set
print("Extracting feature vectors for visualization...")
all_features = []
all_labels = []

for images, labels in test_ds_low_mem:
    # Use the second output of our unified model
    _, features = unified_model.predict(images, verbose=0)
    all_features.append(features)
    all_labels.extend(labels['classification_output'].numpy().flatten())

all_features = np.concatenate(all_features, axis=0)
all_labels = np.array(all_labels)

# 2. Run t-SNE (Reduces 256D down to 2D for plotting)
tsne = TSNE(n_components=2, random_state=SEED)
low_dim_features = tsne.fit_transform(all_features)

# 3. Plot the Clusters
plt.figure(figsize=(10, 7))
df = pd.DataFrame({
    'x': low_dim_features[:, 0],
    'y': low_dim_features[:, 1],
    'Label': ['Autistic' if l == 1 else 'Non-Autistic' for l in all_labels]
})

sns.scatterplot(data=df, x='x', y='y', hue='Label', palette='viridis', alpha=0.7)
plt.title('t-SNE Visualization: How the Model Groups Facial Features')
plt.show()

# %%
# Save the final model for deployment
model_save_path = r"C:\Users\Yasindu\Desktop\Stuff\1.SLIIT\Research\Project\Models\ASD_Model_4.h5"
unified_model.save(model_save_path)

print(f"Project Complete! Model saved to: {model_save_path}")

# %%
import shutil
import os

# 1. Define destination
DEST_TEST_DIR = r"C:\Users\Yasindu\Desktop\Stuff\1.SLIIT\Research\Project\ModelTestingIMGS\model4"

# 2. Get the paths from the original remaining_ds before it was prefetched
# Since test_ds = remaining_ds.take(val_batches // 2)
all_paths = remaining_ds.file_paths
num_test_files = (val_batches // 2).numpy() * BATCH_SIZE 
# Note: we use the number of samples to slice the list of paths
test_paths = all_paths[:num_test_files]

print(f"Recovered {len(test_paths)} file paths.")
print(f"Starting copy...")

files_copied = 0
for path in test_paths:
    class_name = os.path.basename(os.path.dirname(path))
    target_dir = os.path.join(DEST_TEST_DIR, class_name)
    
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
    
    shutil.copy(path, os.path.join(target_dir, os.path.basename(path)))
    files_copied += 1

print(f"\n✅ SUCCESS! Copied {files_copied} images to {DEST_TEST_DIR}")
